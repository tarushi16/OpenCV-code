# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('baby.jpg')
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img_gray = np.float32(img_gray)
plt.imshow(img)

# %%
corner_img = cv2.cornerHarris(img_gray, 2, 5, 0.07)
corner_img = cv2.dilate(corner_img,  None)
img[corner_img > 0.01 * corner_img.maz()] = [0, 0 , 255]
plt.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1fc8a249ba36> in <module>
# ----> 1 corner_img = cv2.cornerHarris(img_gray, 2, 5, 0.07)
#       2 corner_img = cv2.dilate(corner_img,  None)
#       3 img[corner_img > 0.01 * corner_img.maz()] = [0, 0 , 255]
#       4 plt.imshow(img)
#
# NameError: name 'cv2' is not defined
